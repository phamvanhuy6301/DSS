# %%
import numpy as np
import pandas as pd

# %%
book_data = pd.read_csv('C:/Users/ADMIN/OneDrive - Hanoi University of Science and Technology/2022-2/Hệ hỗ trợ quyết định/archive/book_data.csv')
book_data.head(5)
# Out:
#    product_id                            title                    authors  \
# 0    74021317             Cây Cam Ngọt Của Tôi  José Mauro de Vasconcelos
# 1    74021317             Cây Cam Ngọt Của Tôi  José Mauro de Vasconcelos
# 2   184466860  Hành Tinh Của Một Kẻ Nghĩ Nhiều       Nguyễn Đoàn Minh Thư
# 3    73787185         Những Tù Nhân Của Địa Lý               Tim Marshall
# 4    52789367       Nhà Giả Kim (Tái Bản 2020)               Paulo Coelho
#
#    original_price  current_price  quantity                    category  \
# 0          108000          64800   53075.0                 Tiểu Thuyết
# 1          108000          64800   53075.0                 Tiểu Thuyết
# 2           86000          59900    7929.0  Sách tư duy - Kỹ năng sống
# 3          210000         126000   17896.0               Lĩnh vực khác
# 4           79000          47400   24668.0          Tác phẩm kinh điển
#
#    n_review  avg_rating pages              manufacturer  \
# ...

# %%
len(book_data)
# Out:
# 1796

# %%
book_id = pd.read_csv('C:/Users/ADMIN/OneDrive - Hanoi University of Science and Technology/2022-2/Hệ hỗ trợ quyết định/archive/book_id.csv')
book_id.head(5)
# Out:
#           id
# 0   74021317
# 1   74021317
# 2  184466860
# 3   73787185
# 4   52789367

# %%
comments = pd.read_csv('C:/Users/ADMIN/OneDrive - Hanoi University of Science and Technology/2022-2/Hệ hỗ trợ quyết định/archive/comments.csv')
comments.head(5)
# Out:
#    product_id  comment_id            title  thank_count  customer_id  rating  \
# 0    74021317    12559756  Cực kì hài lòng          313     22051463       5
# 1    74021317    16979365  Cực kì hài lòng            6     27791831       5
# 2    74021317    14069617  Cực kì hài lòng           25     17748750       5
# 3    74021317     8569824  Cực kì hài lòng           57       410797       5
# 4    74021317    18368714  Cực kì hài lòng            0     28545286       5
#
#                                              content
# 0  Có những người bước đến, họ lấp đầy hạnh phúc ...
# 1  Thấy nhiều bạn chê tiki gói hàng quá, may sao ...
# 2  Bìa cực xinh, tiki giao hàng nhanh, sách không...
# 3  Sách lúc nhận hình thức rất ổn, không cong vên...
# 4  Một cuốn sách rất đáng đọc về tình yêu thương ...

# %%
len(comments)
# Out:
# 141281

# %%
prepared_data_book = pd.read_csv('C:/Users/ADMIN/OneDrive - Hanoi University of Science and Technology/2022-2/Hệ hỗ trợ quyết định/archive/prepared_data_book.csv')
prepared_data_book.head(5)
# Out:
#    Unnamed: 0  product_id                             title  \
# 0           0    74021317              Cây Cam Ngọt Của Tôi
# 1           2   184466860   Hành Tinh Của Một Kẻ Nghĩ Nhiều
# 2           3    73787185          Những Tù Nhân Của Địa Lý
# 3           4    52789367        Nhà Giả Kim (Tái Bản 2020)
# 4           5   147920903  Một Thoáng Ta Rực Rỡ Ở Nhân Gian
#
#                      authors  original_price  current_price  quantity  \
# 0  José Mauro de Vasconcelos          108000          64800     53075
# 1       Nguyễn Đoàn Minh Thư           86000          59900      7929
# 2               Tim Marshall          210000         126000     17896
# 3               Paulo Coelho           79000          47400     24668
# 4                    Unknown          135000          81000     10000
#
#              category  n_review  avg_rating  pages              manufacturer  \
# 0         Tiểu Thuyết     11481         5.0    244  Nhà Xuất Bản Hội Nhà Văn
# ...

# %%
df = { 'product_id': [],
               'title': [], 
               'author': [],
               'original_price': [], 
               'current_price': [], 
               'quantity': [],
               'category': [], 
               'n_review': [], 
               'avg_rating': [],
               'pages': [], 
               'manufacturer': [], 
               'discount': []}
df = pd.DataFrame(df)

# %%
import DanhSach

# %%
D = DanhSach.DanhSach()
D.addnewbook('bum', 158307840)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\ADMIN\OneDrive - Hanoi University of Science and Technology\2022-2\Hệ hỗ trợ quyết định\archive\dataprocess.ipynb Cell 10 in 2
#       <a href='vscode-notebook-cell:/c%3A/Users/ADMIN/OneDrive%20-%20Hanoi%20University%20of%20Science%20and%20Technology/2022-2/H%E1%BB%87%20h%E1%BB%97%20tr%E1%BB%A3%20quy%E1%BA%BFt%20%C4%91%E1%BB%8Bnh/archive/dataprocess.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> D = DanhSach.DanhSach()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ADMIN/OneDrive%20-%20Hanoi%20University%20of%20Science%20and%20Technology/2022-2/H%E1%BB%87%20h%E1%BB%97%20tr%E1%BB%A3%20quy%E1%BA%BFt%20%C4%91%E1%BB%8Bnh/archive/dataprocess.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> D.addnewbook('bum', 158307840)
#
# ...
